# %%
{
    "nbformat": 4,
    "nbformat_minor": 5,
    "metadata": {
        "kernelspec": {
            "display_name": "Python 3",
            "language": "python",
            "name": "python3"
        },
        "language_info": {
            "name": "python",
            "version": "3.x"
        }
    },
    "cells": [
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "\"\"\"\n",
                "Author: Siddhant Bhardwaj and Sivadhanushya\n",
                "Team Name: SoilClassifiers\n",
                "Team Members: Member-1, Member-2, Member-3, Member-4, Member-5\n",
                "Leaderboard Rank: \n",
                "\"\"\"\n"
            ]
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "# Project Card: Soil Classification Pipeline\n",
                "\n",
                "## 📖 Overview\n",
                "This project implements a soil type classification pipeline using EfficientNet-B1 and Optuna for hyperparameter tuning. The goal is to classify images of soil into four categories: Alluvial, Black, Clay, and Red soils."
            ]
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "## 🔧 Repository Structure\n",
                "- `preprocessing.py`: data loaders and transforms\n",
                "- `postprocessing.py`: submission builder\n",
                "- `training.ipynb`: model training with hyperparameter tuning\n",
                "- `inference.ipynb`: model inference and submission generation\n",
                "- `requirements.txt`: dependencies\n",
                "- `projectcard.ipynb`: this project summary"
            ]
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "## 🛠️ Requirements\n",
                "Install dependencies with:\n",
                "```bash\n",
                "pip install -r requirements.txt\n",
                "```"
            ]
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "## 🚀 Usage\n",
                "1. **Training**: Open and run `training.ipynb` to train the model and save the best checkpoint.\n",
                "2. **Inference**: Open and run `inference.ipynb` to generate predictions on the test set.\n",
                "3. **Submission**: The submission file will be saved as `submission.csv` in the output directory."
            ]
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "## 📊 Metrics\n",
                "- Minimum per-class F1-score on validation: 0.9398\n",
                "- Accuracy on validation: 0.9510"
            ]
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "## 📂 Data\n",
                "Dataset is organized under `/kaggle/input/soil-classification/soil_classification-2025` with:\n",
                "- `train/`: training images\n",
                "- `test/`: test images\n",
                "- `train_labels.csv`: image IDs and labels for training\n",
                "- `test_ids.csv`: image IDs for test set"
            ]
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "## 📜 License\n",
                "Specify your project license here."
            ]
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "---\n",
                "Author: Siddhant Bhardwaj and Sivadhanushya\n"
            ]
        }
    ]
}

# %% [markdown]
# {
#     "nbformat": 4,
#     "nbformat_minor": 5,
#     "metadata": {
#         "kernelspec": {
#             "display_name": "Python 3",
#             "language": "python",
#             "name": "python3"
#         },
#         "language_info": {
#             "name": "python",
#             "version": "3.x"
#         }
#     },
#     "cells": [
#         {
#             "cell_type": "markdown",
#             "metadata": {},
#             "source": [
#                 "\"\"\"\n",
#                 "Author: Siddhant Bhardwaj and Sivadhanushya\n",
#                 "Team Name: SoilClassifiers\n",
#                 "Team Members: Member-1, Member-2, Member-3, Member-4, Member-5\n",
#                 "Leaderboard Rank: \n",
#                 "\"\"\"\n"
#             ]
#         },
#         {
#             "cell_type": "markdown",
#             "metadata": {},
#             "source": [
#                 "# Project Card: Soil Classification Pipeline\n",
#                 "\n",
#                 "## 📖 Overview\n",
#                 "This project implements a soil type classification pipeline using EfficientNet-B1 and Optuna for hyperparameter tuning. The goal is to classify images of soil into four categories: Alluvial, Black, Clay, and Red soils."
#             ]
#         },
#         {
#             "cell_type": "markdown",
#             "metadata": {},
#             "source": [
#                 "## 🔧 Repository Structure\n",
#                 "- `preprocessing.py`: data loaders and transforms\n",
#                 "- `postprocessing.py`: submission builder\n",
#                 "- `training.ipynb`: model training with hyperparameter tuning\n",
#                 "- `inference.ipynb`: model inference and submission generation\n",
#                 "- `requirements.txt`: dependencies\n",
#                 "- `projectcard.ipynb`: this project summary"
#             ]
#         },
#         {
#             "cell_type": "markdown",
#             "metadata": {},
#             "source": [
#                 "## 🛠️ Requirements\n",
#                 "Install dependencies with:\n",
#                 "```bash\n",
#                 "pip install -r requirements.txt\n",
#                 "```"
#             ]
#         },
#         {
#             "cell_type": "markdown",
#             "metadata": {},
#             "source": [
#                 "## 🚀 Usage\n",
#                 "1. **Training**: Open and run `training.ipynb` to train the model and save the best checkpoint.\n",
#                 "2. **Inference**: Open and run `inference.ipynb` to generate predictions on the test set.\n",
#                 "3. **Submission**: The submission file will be saved as `submission.csv` in the output directory."
#             ]
#         },
#         {
#             "cell_type": "markdown",
#             "metadata": {},
#             "source": [
#                 "## 📊 Metrics\n",
#                 "- Minimum per-class F1-score on validation: 0.9398\n",
#                 "- Accuracy on validation: 0.9510"
#             ]
#         },
#         {
#             "cell_type": "markdown",
#             "metadata": {},
#             "source": [
#                 "## 📂 Data\n",
#                 "Dataset is organized under `/kaggle/input/soil-classification/soil_classification-2025` with:\n",
#                 "- `train/`: training images\n",
#                 "- `test/`: test images\n",
#                 "- `train_labels.csv`: image IDs and labels for training\n",
#                 "- `test_ids.csv`: image IDs for test set"
#             ]
#         },
#         {
#             "cell_type": "markdown",
#             "metadata": {},
#             "source": [
#                 "## 📜 License\n",
#                 "Specify your project license here."
#             ]
#         },
#         {
#             "cell_type": "markdown",
#             "metadata": {},
#             "source": [
#                 "---\n",
#                 "Generated by Annam.ai IIT Ropar"
#             ]
#         }
#     ]
# }
